# %% [markdown]
# <a href="https://colab.research.google.com/github/easyMil/Is_Individual/blob/main/fl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from io import StringIO
import lxml.etree as et
from string import ascii_lowercase
from statistics import median_low
import sklearn

srch=pd.read_csv("/content/drive/MyDrive/Copy of search_data.csv")
srch.head(10).T
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                                       0  \
# search_id                          02c6c2ad-325b-4155-bb03-89badc92ea84
# search_time                                         2017-02-01 00:00:07
# currency                                                            USD
# destination                                                         MIA
# search_user_id        NBYNv9utORVjlf604rUgXL/eFz6Tmu2NyygDWTFsM5OOWH...
# language                                                             en
# origin                                                              LAX
# partner_id                                                          294
# passengers                                                            1
# pos                                                                  US
# session_id                         292c32ab-9744-490f-911a-d3536e86847e
# user_agent            Dalvik/2.1.0 (Linux; U; Android 6.0.1; SM-G920...
# num_requests                                                          1
# fare                                                              499.0
# supplier                                                             22
# cabin_class                                                     economy
# carrier_1                                                            AA
# carrier_2                                                            AA
# flight_num_1                                                     AA1088
# flight_num_2                                                     AA1147
# departure_datetime_1                          2017-04-07T09:50:00-07:00
# arrival_datetime_1                            2017-04-07T17:56:00-04:00
# departure_datetime_2                          2017-04-16T21:30:00-04:00
# arrival_datetime_2                            2017-04-17T00:33:00-07:00
# itinerary_id                       294f363b-86f0-4e67-abe9-05221dadb8b8
#
#                                                                       1  \
# search_id                          0280e382-d24e-4138-bb20-8d236c0bb02f
# search_time                                         2017-02-01 00:00:32
# currency                                                            ISK
# destination                                                         VCE
# search_user_id                     c2ea8bd4-40ff-4b8b-a42f-ada9b02ef963
# language                                                             en
# origin                                                              REK
# partner_id                                                           58
# passengers                                                            1
# pos                                                                  IS
# session_id                         d34dd58d-aec5-4d8f-abf7-090db2e011bd
# user_agent            Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2...
# num_requests                                                          7
# fare                                                            25895.0
# supplier                                                            103
# cabin_class                                                     Economy
# carrier_1                                                        FI; IB
# carrier_2                                                           NaN
# flight_num_1                                              FI540; IB5120
# flight_num_2                                                        NaN
# departure_datetime_1           2017-06-10T01:05:00; 2017-06-10T14:50:00
# arrival_datetime_1             2017-06-10T06:20:00; 2017-06-10T16:40:00
# departure_datetime_2                                                NaN
# arrival_datetime_2                                                  NaN
# itinerary_id                       d9592a05-c850-4abd-9cf1-9fe8343d556c
#
#                                                                       2  \
# search_id                          c8903983-3eb9-4f0f-8f87-64b7e5dd0692
# search_time                                         2017-02-01 00:00:39
# currency                                                            USD
# destination                                                         SJD
# search_user_id                     36195bda-ec40-4907-9428-c4fe11bd87fa
# language                                                             en
# origin                                                              LAX
# partner_id                                                           91
# passengers                                                            1
# pos                                                                  US
# session_id                         e0ae1ecd-8715-4577-bca4-604cf3a58d0e
# user_agent            Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG-SM-...
# num_requests                                                          1
# fare                                                             286.79
# supplier                                                             91
# cabin_class                                                     economy
# carrier_1                                                            AA
# carrier_2                                                            AA
# flight_num_1                                                      AA237
# flight_num_2                                                      AA237
# departure_datetime_1                                2017-05-30T08:35:00
# arrival_datetime_1                                  2017-05-30T11:58:00
# departure_datetime_2                                2017-06-03T13:00:00
# arrival_datetime_2                                  2017-06-03T14:36:00
# itinerary_id                       c53826cf-1fba-42a6-a765-941628e1901e
#
#                                                                       3  \
# search_id                          b1d666c8-d570-47ec-bc46-26ee5332620f
# search_time                                         2017-02-01 00:00:48
# currency                                                            USD
# destination                                                         LHR
# search_user_id                     36ba8a8c-8c47-4dc6-bd70-0b3ae071c8cf
# language                                                             en
# origin                                                              PHX
# partner_id                                                           91
# passengers                                                            2
# pos                                                                  US
# session_id                         1eb74ec2-e6d7-4423-a1e3-de2a411a4aed
# user_agent            Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...
# num_requests                                                          1
# fare                                                             507.46
# supplier                                                             91
# cabin_class                                                     economy
# carrier_1                                                        DL; DL
# carrier_2                                                        DL; DL
# flight_num_1                                             DL5852; DL4414
# flight_num_2                                               DL11; DL1516
# departure_datetime_1           2017-05-10T13:13:00; 2017-05-10T18:30:00
# arrival_datetime_1             2017-05-10T14:45:00; 2017-05-11T12:55:00
# departure_datetime_2           2017-05-28T12:55:00; 2017-05-28T17:50:00
# arrival_datetime_2             2017-05-28T16:05:00; 2017-05-28T19:11:00
# itinerary_id                       37a44686-8347-4c72-8690-c9432349f9a6
#
#                                                                       4  \
# search_id                          020521d7-ea85-49dd-97e2-1ae662f432a9
# search_time                                         2017-02-01 00:00:48
# currency                                                            ISK
# destination                                                         BFS
# search_user_id                     cc24b343-7e53-48b4-9bdb-092a49381665
# language                                                             is
# origin                                                              REK
# partner_id                                                           58
# passengers                                                            2
# pos                                                                  IS
# session_id                         a3056056-6db5-44df-bca4-01a3bf8d9ff5
# user_agent            Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# num_requests                                                         10
# fare                                                           47717.49
# supplier                                                            103
# cabin_class                                                     Economy
# carrier_1                                                        FI; FR
# carrier_2                                                        FR; U2
# flight_num_1                                              FI470; FR1274
# flight_num_2                                             FR1138; U28507
# departure_datetime_1           2017-04-12T07:35:00; 2017-04-12T18:10:00
# arrival_datetime_1             2017-04-12T11:35:00; 2017-04-12T19:35:00
# departure_datetime_2           2017-04-19T20:00:00; 2017-04-20T06:30:00
# arrival_datetime_2             2017-04-19T21:20:00; 2017-04-20T08:45:00
# itinerary_id                       52248983-0449-411f-9794-88c7bc098faa
#
#                                                                       5  \
# search_id                          0abbfe4c-b72d-42c7-ae8a-966643e14600
# search_time                                         2017-02-01 00:00:54
# currency                                                            USD
# destination                                                         LAX
# search_user_id                     025ee32b-2a0b-4987-b275-893f148ab259
# language                                                             en
# origin                                                              CMH
# partner_id                                                           91
# passengers                                                            1
# pos                                                                  US
# session_id                         262b200e-b183-48ab-b737-72c251ca0ff3
# user_agent            Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1...
# num_requests                                                          1
# fare                                                              192.2
# supplier                                                             91
# cabin_class                                                     economy
# carrier_1                                                            AA
# carrier_2                                                           NaN
# flight_num_1                                                      AA659
# flight_num_2                                                        NaN
# departure_datetime_1                                2017-03-29T16:35:00
# arrival_datetime_1                                  2017-03-29T18:53:00
# departure_datetime_2                                                NaN
# arrival_datetime_2                                                  NaN
# itinerary_id                       2e3afcd8-7d56-4b49-a71b-f85c23e1b807
#
#                                                                       6  \
# search_id                          198f2d0f-4f30-418c-bf78-ccf776a63501
# search_time                                         2017-02-01 00:01:02
# currency                                                            USD
# destination                                                         MCO
# search_user_id                     f69465d7-cdb2-4dd0-98ad-6362423a8dc3
# language                                                             en
# origin                                                              EGE
# partner_id                                                           91
# passengers                                                            1
# pos                                                                  US
# session_id                         97d78806-2f65-48af-9d21-e7f9bb6a667c
# user_agent            Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# num_requests                                                          1
# fare                                                              615.6
# supplier                                                             91
# cabin_class                                                     economy
# carrier_1                                                        UA; UA
# carrier_2                                                        UA; UA
# flight_num_1                                              UA4475; UA564
# flight_num_2                                             UA1191; UA1252
# departure_datetime_1           2017-02-10T07:52:00; 2017-02-10T11:00:00
# arrival_datetime_1             2017-02-10T09:03:00; 2017-02-10T16:31:00
# departure_datetime_2           2017-02-13T08:47:00; 2017-02-13T11:40:00
# arrival_datetime_2             2017-02-13T10:30:00; 2017-02-13T13:41:00
# itinerary_id                       619b0f7c-825f-47b1-a191-300862feff80
#
#                                                                       7  \
# search_id                          03224bb7-924c-4044-9f4b-033c3850447d
# search_time                                         2017-02-01 00:01:06
# currency                                                            USD
# destination                                                         NYC
# search_user_id                     e68fb852-92c5-4ec4-8d6d-3c1549c749f2
# language                                                             en
# origin                                                              YTO
# partner_id                                                           58
# passengers                                                            1
# pos                                                                  RU
# session_id                         098bf286-4f80-4981-a723-e8c063cb5910
# user_agent            Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# num_requests                                                         10
# fare                                                             150.04
# supplier                                                            148
# cabin_class                                                     Economy
# carrier_1                                                        DL; DL
# carrier_2                                                           NaN
# flight_num_1                                             DL1822; DL5211
# flight_num_2                                                        NaN
# departure_datetime_1           2017-02-16T06:10:00; 2017-02-16T08:37:00
# arrival_datetime_1             2017-02-16T07:40:00; 2017-02-16T10:33:00
# departure_datetime_2                                                NaN
# arrival_datetime_2                                                  NaN
# itinerary_id                       22b48ef5-4ff1-4356-86e8-4e37226d3bfb
#
#                                                                       8  \
# search_id                          bf0709c2-5775-48aa-952b-35f88430c431
# search_time                                         2017-02-01 00:01:11
# currency                                                            USD
# destination                                                         PBI
# search_user_id                     7864485d-5c63-45ee-9e4d-a3c43e078b36
# language                                                             en
# origin                                                              FLO
# partner_id                                                           91
# passengers                                                            3
# pos                                                                  US
# session_id                         6619e1b4-7335-4ff3-9b9b-88bdc65ed715
# user_agent            Mozilla/5.0 (Linux; Android 6.0; RCT6513W87 Bu...
# num_requests                                                          1
# fare                                                              352.6
# supplier                                                             91
# cabin_class                                                     economy
# carrier_1                                                        AA; AA
# carrier_2                                                        AA; AA
# flight_num_1                                             AA4933; AA1846
# flight_num_2                                              AA539; AA4860
# departure_datetime_1           2017-05-26T05:25:00; 2017-05-26T07:40:00
# arrival_datetime_1             2017-05-26T06:16:00; 2017-05-26T09:31:00
# departure_datetime_2           2017-05-28T08:25:00; 2017-05-28T13:00:00
# arrival_datetime_2             2017-05-28T10:18:00; 2017-05-28T13:50:00
# itinerary_id                       ead1e4c6-6d82-4aed-9d65-94e4b4d67ab0
#
#                                                                       9
# search_id                          e929ab63-6a18-4221-9311-5f9290fbefd6
# search_time                                         2017-02-01 00:01:18
# currency                                                            USD
# destination                                                         LHR
# search_user_id                     b1a66917-ca3e-457e-8bb2-79b6cd86ca7c
# language                                                             en
# origin                                                              SFO
# partner_id                                                           91
# passengers                                                            1
# pos                                                                  US
# session_id                         4651b45f-2325-48e2-b55e-e4fd60994d6f
# user_agent            Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2...
# num_requests                                                          1
# fare                                                             888.86
# supplier                                                             91
# cabin_class                                                     economy
# carrier_1                                                    TP; TP; TP
# carrier_2                                                    TP; TP; TP
# flight_num_1                                       TP8052; TP218; TP352
# flight_num_2                                       TP353; TP209; TP8051
# departure_datetime_1  2017-03-06T08:00:00; 2017-03-06T20:00:00; 2017...
# arrival_datetime_1    2017-03-06T16:35:00; 2017-03-07T07:15:00; 2017...
# departure_datetime_2  2017-03-09T06:00:00; 2017-03-09T16:50:00; 2017...
# arrival_datetime_2    2017-03-09T08:35:00; 2017-03-09T20:15:00; 2017...
# itinerary_id                       b84a4eca-fd5f-4794-afaa-e1d0e7231537

# %%
srch.isna().sum().sort_values()
# Out:
# search_id                     0
# arrival_datetime_1            0
# departure_datetime_1          0
# flight_num_1                  0
# carrier_1                     0
# cabin_class                   0
# supplier                      0
# fare                          0
# session_id                    0
# num_requests                  0
# passengers                    0
# partner_id                    0
# origin                        0
# language                      0
# search_user_id                0
# destination                   0
# currency                      0
# search_time                   0
# pos                        5107
# user_agent                 8145
# arrival_datetime_2       234400
# carrier_2                234400
# flight_num_2             234400
# departure_datetime_2     234400
# itinerary_id            1173941
# dtype: int64

# %%
srch.describe()
# Out:
#          partner_id    passengers  num_requests          fare      supplier
# count  1.277062e+06  1.277062e+06  1.277062e+06  1.277062e+06  1.277062e+06
# mean   9.420261e+01  1.516124e+00  3.557595e+01  5.252630e+03  9.190735e+01
# std    1.943412e+01  9.980720e-01  1.875707e+01  5.449013e+05  1.583531e+01
# min    5.800000e+01  0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    9.100000e+01  1.000000e+00  4.000000e+01  2.984200e+02  9.100000e+01
# 50%    9.100000e+01  1.000000e+00  4.000000e+01  4.482000e+02  9.100000e+01
# 75%    9.100000e+01  2.000000e+00  4.000000e+01  7.057100e+02  9.100000e+01
# max    2.940000e+02  1.000000e+02  3.450000e+02  3.115879e+08  3.280000e+02

# %%
arp=pd.read_csv("/content/drive/MyDrive/Copy of airport_data.csv")
arp.head(10).T
# Out:
#                             0              1              2        3  \
# iata_code                 NYC            QSF            CHI      PAR
# city                 New York  San Francisco        Chicago    Paris
# country         United States  United States  United States   France
# latitude              40.7142            NaN        41.8836  48.8564
# longitude            -74.0058            NaN       -87.6317  2.35222
# altitude                 31.0            NaN          596.0    107.0
# timezone                 -5.0           -8.0           -6.0      1.0
# dst                         A            NaN              A        E
# aggregate_code            1.0            1.0            1.0      1.0
#
#                             4               5              6              7  \
# iata_code                 WAS             LON            DFW            HOU
# city               Washington          London         Dallas        Houston
# country         United States  United Kingdom  United States  United States
# latitude              38.8894         51.5081            NaN            NaN
# longitude            -77.0353       -0.127778            NaN            NaN
# altitude                 25.0            66.0            NaN            NaN
# timezone                 -5.0             0.0           -6.0           -6.0
# dst                         A               E            NaN            NaN
# aggregate_code            1.0             1.0            1.0            1.0
#
#                       8       9
# iata_code           BER     MOW
# city             Berlin  Moscow
# country         Germany  Russia
# latitude            NaN     NaN
# longitude           NaN     NaN
# altitude            NaN     NaN
# timezone            1.0     3.0
# dst                 NaN     NaN
# aggregate_code      1.0     1.0

# %%
arp[arp['aggregate_code']==0].isna().sum().sort_values()
# Out:
# iata_code          0
# city               0
# country            0
# timezone           0
# dst                0
# aggregate_code     0
# latitude           2
# longitude          2
# altitude          14
# dtype: int64

# %%
cars.groupby(['marka','pochodzenie']).count()
# Out:
#                    przebieg  spalanie
# marka pochodzenie
# Ford  używany           151       151
#       z niemiec         129       129
# UAZ   używany           280       280
#       z niemiec         224       224
# VW    używany           105       105
#       z niemiec         111       111
